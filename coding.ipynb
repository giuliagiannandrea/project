# %%
import networkx as nx
import matplotlib.pyplot as plt

def read_node_file(file_path):
    nodes = []
    with open(file_path, 'r') as f:
        for line in f:
            parts = line.strip().split('\t')
            node_id = parts[0]
            node_name = parts[1]
            node_type = parts[2]
            nodes.append((node_id, node_name, node_type))
    return nodes

def read_edge_file(file_path):
    edges = []
    with open(file_path, 'r') as f:
        for line in f:
            parts = line.strip().split('\t')
            source = parts[0]
            target = parts[1]
            metaedge = parts[2]
            edges.append((source, target, metaedge))
    return edges

# File paths for nodes and edges
node_file_path = 'hetionet-v1.0-nodes.tsv'
edge_file_path = 'edges.sif'

# Read node and edge data
nodes_data = read_node_file(node_file_path)
edges_data = read_edge_file(edge_file_path)

edges_data = edges_data[1:]
edges_data
nodes_data = nodes_data[1:]  
nodes_data

# %%
d = [x[0] for x in nodes_data]
v = [x[2] for x in nodes_data]

nodes_stripped = [(x, y) for x, y in zip(d, v)]

nodes_stripped
# Out:
# [('Anatomy::UBERON:0000002', 'Anatomy'),
#  ('Anatomy::UBERON:0000004', 'Anatomy'),
#  ('Anatomy::UBERON:0000006', 'Anatomy'),
#  ('Anatomy::UBERON:0000007', 'Anatomy'),
#  ('Anatomy::UBERON:0000010', 'Anatomy'),
#  ('Anatomy::UBERON:0000011', 'Anatomy'),
#  ('Anatomy::UBERON:0000013', 'Anatomy'),
#  ('Anatomy::UBERON:0000020', 'Anatomy'),
#  ('Anatomy::UBERON:0000026', 'Anatomy'),
#  ('Anatomy::UBERON:0000029', 'Anatomy'),
#  ('Anatomy::UBERON:0000033', 'Anatomy'),
#  ('Anatomy::UBERON:0000038', 'Anatomy'),
#  ('Anatomy::UBERON:0000042', 'Anatomy'),
#  ('Anatomy::UBERON:0000043', 'Anatomy'),
#  ('Anatomy::UBERON:0000045', 'Anatomy'),
#  ('Anatomy::UBERON:0000053', 'Anatomy'),
#  ('Anatomy::UBERON:0000054', 'Anatomy'),
#  ('Anatomy::UBERON:0000056', 'Anatomy'),
#  ('Anatomy::UBERON:0000057', 'Anatomy'),
#  ('Anatomy::UBERON:0000165', 'Anatomy'),
#  ('Anatomy::UBERON:0000178', 'Anatomy'),
#  ('Anatomy::UBERON:0000211', 'Anatomy'),
#  ('Anatomy::UBERON:0000473', 'Anatomy'),
#  ('Anatomy::UBERON:0000474', 'Anatomy'),
#  ('Anatomy::UBERON:0000482', 'Anatomy'),
#  ('Anatomy::UBERON:0000483', 'Anatomy'),
#  ('Anatomy::UBERON:0000922', 'Anatomy'),
#  ('Anatomy::UBERON:0000941', 'Anatomy'),
#  ('Anatomy::UBERON:0000946', 'Anatomy'),
#  ('Anatomy::UBERON:0000948', 'Anatomy'),
#  ('Anatomy::UBERON:0000949', 'Anatomy'),
#  ('Anatomy::UBERON:0000955', 'Anatomy'),
#  ('Anatomy::UBERON:0000959', 'Anatomy'),
#  ('Anatomy::UBERON:0000964', 'Anatomy'),
#  ('Anatomy::UBERON:0000966', 'Anatomy'),
#  ('Anatomy::UBERON:0000970', 'Anatomy'),
#  ('Anatomy::UBERON:0000974', 'Anatomy'),
#  ('Anatomy::UBERON:0000975', 'Anatomy'),
#  ('Anatomy::UBERON:0000977', 'Anatomy'),
#  ('Anatomy::UBERON:0000978', 'Anatomy'),
#  ('Anatomy::UBERON:0000982', 'Anatomy'),
#  ('Anatomy::UBERON:0000985', 'Anatomy'),
#  ('Anatomy::UBERON:0000988', 'Anatomy'),
#  ('Anatomy::UBERON:0000989', 'Anatomy'),
#  ('Anatomy::UBERON:0000991', 'Anatomy'),
#  ('Anatomy::UBERON:0000992', 'Anatomy'),
#  ('Anatomy::UBERON:0000993', 'Anatomy'),
#  ('Anatomy::UBERON:0000995', 'Anatomy'),
#  ('Anatomy::UBERON:0000996', 'Anatomy'),
#  ('Anatomy::UBERON:0000997', 'Anatomy'),
#  ('Anatomy::UBERON:0000998', 'Anatomy'),
#  ('Anatomy::UBERON:0000999', 'Anatomy'),
#  ('Anatomy::UBERON:0001000', 'Anatomy'),
#  ('Anatomy::UBERON:0001003', 'Anatomy'),
#  ('Anatomy::UBERON:0001004', 'Anatomy'),
#  ('Anatomy::UBERON:0001007', 'Anatomy'),
#  ('Anatomy::UBERON:0001008', 'Anatomy'),
#  ('Anatomy::UBERON:0001011', 'Anatomy'),
#  ('Anatomy::UBERON:0001013', 'Anatomy'),
#  ('Anatomy::UBERON:0001016', 'Anatomy'),
#  ('Anatomy::UBERON:0001017', 'Anatomy'),
#  ('Anatomy::UBERON:0001021', 'Anatomy'),
#  ('Anatomy::UBERON:0001031', 'Anatomy'),
#  ('Anatomy::UBERON:0001037', 'Anatomy'),
#  ('Anatomy::UBERON:0001044', 'Anatomy'),
#  ('Anatomy::UBERON:0001064', 'Anatomy'),
#  ('Anatomy::UBERON:0001067', 'Anatomy'),
#  ('Anatomy::UBERON:0001070', 'Anatomy'),
#  ('Anatomy::UBERON:0001072', 'Anatomy'),
#  ('Anatomy::UBERON:0001088', 'Anatomy'),
#  ('Anatomy::UBERON:0001089', 'Anatomy'),
#  ('Anatomy::UBERON:0001090', 'Anatomy'),
#  ('Anatomy::UBERON:0001093', 'Anatomy'),
#  ('Anatomy::UBERON:0001103', 'Anatomy'),
#  ('Anatomy::UBERON:0001105', 'Anatomy'),
#  ('Anatomy::UBERON:0001111', 'Anatomy'),
#  ('Anatomy::UBERON:0001130', 'Anatomy'),
#  ('Anatomy::UBERON:0001132', 'Anatomy'),
#  ('Anatomy::UBERON:0001135', 'Anatomy'),
#  ('Anatomy::UBERON:0001140', 'Anatomy'),
#  ('Anatomy::UBERON:0001143', 'Anatomy'),
#  ('Anatomy::UBERON:0001148', 'Anatomy'),
#  ('Anatomy::UBERON:0001174', 'Anatomy'),
#  ('Anatomy::UBERON:0001175', 'Anatomy'),
#  ('Anatomy::UBERON:0001182', 'Anatomy'),
#  ('Anatomy::UBERON:0001183', 'Anatomy'),
#  ('Anatomy::UBERON:0001184', 'Anatomy'),
#  ('Anatomy::UBERON:0001193', 'Anatomy'),
#  ('Anatomy::UBERON:0001194', 'Anatomy'),
#  ('Anatomy::UBERON:0001224', 'Anatomy'),
#  ('Anatomy::UBERON:0001225', 'Anatomy'),
#  ('Anatomy::UBERON:0001228', 'Anatomy'),
#  ('Anatomy::UBERON:0001231', 'Anatomy'),
#  ('Anatomy::UBERON:0001232', 'Anatomy'),
#  ('Anatomy::UBERON:0001235', 'Anatomy'),
#  ('Anatomy::UBERON:0001236', 'Anatomy'),
#  ('Anatomy::UBERON:0001237', 'Anatomy'),
#  ('Anatomy::UBERON:0001264', 'Anatomy'),
#  ('Anatomy::UBERON:0001267', 'Anatomy'),
#  ('Anatomy::UBERON:0001283', 'Anatomy'),
#  ('Anatomy::UBERON:0001285', 'Anatomy'),
#  ('Anatomy::UBERON:0001288', 'Anatomy'),
#  ('Anatomy::UBERON:0001295', 'Anatomy'),
#  ('Anatomy::UBERON:0001296', 'Anatomy'),
#  ('Anatomy::UBERON:0001300', 'Anatomy'),
#  ('Anatomy::UBERON:0001305', 'Anatomy'),
#  ('Anatomy::UBERON:0001310', 'Anatomy'),
#  ('Anatomy::UBERON:0001322', 'Anatomy'),
#  ('Anatomy::UBERON:0001323', 'Anatomy'),
#  ('Anatomy::UBERON:0001324', 'Anatomy'),
#  ('Anatomy::UBERON:0001343', 'Anatomy'),
#  ('Anatomy::UBERON:0001348', 'Anatomy'),
#  ('Anatomy::UBERON:0001352', 'Anatomy'),
#  ('Anatomy::UBERON:0001361', 'Anatomy'),
#  ('Anatomy::UBERON:0001365', 'Anatomy'),
#  ('Anatomy::UBERON:0001394', 'Anatomy'),
#  ('Anatomy::UBERON:0001398', 'Anatomy'),
#  ('Anatomy::UBERON:0001404', 'Anatomy'),
#  ('Anatomy::UBERON:0001406', 'Anatomy'),
#  ('Anatomy::UBERON:0001437', 'Anatomy'),
#  ('Anatomy::UBERON:0001456', 'Anatomy'),
#  ('Anatomy::UBERON:0001460', 'Anatomy'),
#  ('Anatomy::UBERON:0001461', 'Anatomy'),
#  ('Anatomy::UBERON:0001463', 'Anatomy'),
#  ('Anatomy::UBERON:0001464', 'Anatomy'),
#  ('Anatomy::UBERON:0001465', 'Anatomy'),
#  ('Anatomy::UBERON:0001467', 'Anatomy'),
#  ('Anatomy::UBERON:0001469', 'Anatomy'),
#  ('Anatomy::UBERON:0001470', 'Anatomy'),
#  ('Anatomy::UBERON:0001479', 'Anatomy'),
#  ('Anatomy::UBERON:0001484', 'Anatomy'),
#  ('Anatomy::UBERON:0001485', 'Anatomy'),
#  ('Anatomy::UBERON:0001486', 'Anatomy'),
#  ('Anatomy::UBERON:0001488', 'Anatomy'),
#  ('Anatomy::UBERON:0001490', 'Anatomy'),
#  ('Anatomy::UBERON:0001492', 'Anatomy'),
#  ('Anatomy::UBERON:0001494', 'Anatomy'),
#  ('Anatomy::UBERON:0001515', 'Anatomy'),
#  ('Anatomy::UBERON:0001516', 'Anatomy'),
#  ('Anatomy::UBERON:0001529', 'Anatomy'),
#  ('Anatomy::UBERON:0001530', 'Anatomy'),
#  ('Anatomy::UBERON:0001532', 'Anatomy'),
#  ('Anatomy::UBERON:0001533', 'Anatomy'),
#  ('Anatomy::UBERON:0001535', 'Anatomy'),
#  ('Anatomy::UBERON:0001544', 'Anatomy'),
#  ('Anatomy::UBERON:0001567', 'Anatomy'),
#  ('Anatomy::UBERON:0001577', 'Anatomy'),
#  ('Anatomy::UBERON:0001579', 'Anatomy'),
#  ('Anatomy::UBERON:0001585', 'Anatomy'),
#  ('Anatomy::UBERON:0001587', 'Anatomy'),
#  ('Anatomy::UBERON:0001594', 'Anatomy'),
#  ('Anatomy::UBERON:0001597', 'Anatomy'),
#  ('Anatomy::UBERON:0001598', 'Anatomy'),
#  ('Anatomy::UBERON:0001599', 'Anatomy'),
#  ('Anatomy::UBERON:0001600', 'Anatomy'),
#  ('Anatomy::UBERON:0001616', 'Anatomy'),
#  ('Anatomy::UBERON:0001619', 'Anatomy'),
#  ('Anatomy::UBERON:0001620', 'Anatomy'),
#  ('Anatomy::UBERON:0001624', 'Anatomy'),
#  ('Anatomy::UBERON:0001627', 'Anatomy'),
#  ('Anatomy::UBERON:0001633', 'Anatomy'),
#  ('Anatomy::UBERON:0001636', 'Anatomy'),
#  ('Anatomy::UBERON:0001637', 'Anatomy'),
#  ('Anatomy::UBERON:0001638', 'Anatomy'),
#  ('Anatomy::UBERON:0001640', 'Anatomy'),
#  ('Anatomy::UBERON:0001643', 'Anatomy'),
#  ('Anatomy::UBERON:0001644', 'Anatomy'),
#  ('Anatomy::UBERON:0001645', 'Anatomy'),
#  ('Anatomy::UBERON:0001646', 'Anatomy'),
#  ('Anatomy::UBERON:0001647', 'Anatomy'),
#  ('Anatomy::UBERON:0001648', 'Anatomy'),
#  ('Anatomy::UBERON:0001649', 'Anatomy'),
#  ('Anatomy::UBERON:0001650', 'Anatomy'),
#  ('Anatomy::UBERON:0001673', 'Anatomy'),
#  ('Anatomy::UBERON:0001675', 'Anatomy'),
#  ('Anatomy::UBERON:0001676', 'Anatomy'),
#  ('Anatomy::UBERON:0001677', 'Anatomy'),
#  ('Anatomy::UBERON:0001678', 'Anatomy'),
#  ('Anatomy::UBERON:0001679', 'Anatomy'),
#  ('Anatomy::UBERON:0001681', 'Anatomy'),
#  ('Anatomy::UBERON:0001684', 'Anatomy'),
#  ('Anatomy::UBERON:0001685', 'Anatomy'),
#  ('Anatomy::UBERON:0001687', 'Anatomy'),
#  ('Anatomy::UBERON:0001688', 'Anatomy'),
#  ('Anatomy::UBERON:0001689', 'Anatomy'),
#  ('Anatomy::UBERON:0001690', 'Anatomy'),
#  ('Anatomy::UBERON:0001691', 'Anatomy'),
#  ('Anatomy::UBERON:0001694', 'Anatomy'),
#  ('Anatomy::UBERON:0001697', 'Anatomy'),
#  ('Anatomy::UBERON:0001700', 'Anatomy'),
#  ('Anatomy::UBERON:0001702', 'Anatomy'),
#  ('Anatomy::UBERON:0001705', 'Anatomy'),
#  ('Anatomy::UBERON:0001707', 'Anatomy'),
#  ('Anatomy::UBERON:0001708', 'Anatomy'),
#  ('Anatomy::UBERON:0001710', 'Anatomy'),
#  ('Anatomy::UBERON:0001711', 'Anatomy'),
#  ('Anatomy::UBERON:0001716', 'Anatomy'),
#  ('Anatomy::UBERON:0001717', 'Anatomy'),
#  ('Anatomy::UBERON:0001720', 'Anatomy'),
#  ('Anatomy::UBERON:0001723', 'Anatomy'),
#  ('Anatomy::UBERON:0001724', 'Anatomy'),
#  ('Anatomy::UBERON:0001733', 'Anatomy'),
#  ('Anatomy::UBERON:0001734', 'Anatomy'),
#  ('Anatomy::UBERON:0001736', 'Anatomy'),
#  ('Anatomy::UBERON:0001737', 'Anatomy'),
#  ('Anatomy::UBERON:0001744', 'Anatomy'),
#  ('Anatomy::UBERON:0001750', 'Anatomy'),
#  ('Anatomy::UBERON:0001756', 'Anatomy'),
#  ('Anatomy::UBERON:0001759', 'Anatomy'),
#  ('Anatomy::UBERON:0001760', 'Anatomy'),
#  ('Anatomy::UBERON:0001762', 'Anatomy'),
#  ('Anatomy::UBERON:0001764', 'Anatomy'),
#  ('Anatomy::UBERON:0001768', 'Anatomy'),
#  ('Anatomy::UBERON:0001769', 'Anatomy'),
#  ('Anatomy::UBERON:0001771', 'Anatomy'),
#  ('Anatomy::UBERON:0001772', 'Anatomy'),
#  ('Anatomy::UBERON:0001773', 'Anatomy'),
#  ('Anatomy::UBERON:0001775', 'Anatomy'),
#  ('Anatomy::UBERON:0001776', 'Anatomy'),
#  ('Anatomy::UBERON:0001777', 'Anatomy'),
#  ('Anatomy::UBERON:0001780', 'Anatomy'),
#  ('Anatomy::UBERON:0001783', 'Anatomy'),
#  ('Anatomy::UBERON:0001785', 'Anatomy'),
#  ('Anatomy::UBERON:0001786', 'Anatomy'),
#  ('Anatomy::UBERON:0001796', 'Anatomy'),
#  ('Anatomy::UBERON:0001805', 'Anatomy'),
#  ('Anatomy::UBERON:0001814', 'Anatomy'),
#  ('Anatomy::UBERON:0001815', 'Anatomy'),
#  ('Anatomy::UBERON:0001818', 'Anatomy'),
#  ('Anatomy::UBERON:0001820', 'Anatomy'),
#  ('Anatomy::UBERON:0001821', 'Anatomy'),
#  ('Anatomy::UBERON:0001825', 'Anatomy'),
#  ('Anatomy::UBERON:0001827', 'Anatomy'),
#  ('Anatomy::UBERON:0001831', 'Anatomy'),
#  ('Anatomy::UBERON:0001832', 'Anatomy'),
#  ('Anatomy::UBERON:0001833', 'Anatomy'),
#  ('Anatomy::UBERON:0001836', 'Anatomy'),
#  ('Anatomy::UBERON:0001837', 'Anatomy'),
#  ('Anatomy::UBERON:0001840', 'Anatomy'),
#  ('Anatomy::UBERON:0001844', 'Anatomy'),
#  ('Anatomy::UBERON:0001846', 'Anatomy'),
#  ('Anatomy::UBERON:0001855', 'Anatomy'),
#  ('Anatomy::UBERON:0001860', 'Anatomy'),
#  ('Anatomy::UBERON:0001864', 'Anatomy'),
#  ('Anatomy::UBERON:0001866', 'Anatomy'),
#  ('Anatomy::UBERON:0001884', 'Anatomy'),
#  ('Anatomy::UBERON:0001886', 'Anatomy'),
#  ('Anatomy::UBERON:0001887', 'Anatomy'),
#  ('Anatomy::UBERON:0001890', 'Anatomy'),
#  ('Anatomy::UBERON:0001891', 'Anatomy'),
#  ('Anatomy::UBERON:0001893', 'Anatomy'),
#  ('Anatomy::UBERON:0001895', 'Anatomy'),
#  ('Anatomy::UBERON:0001896', 'Anatomy'),
#  ('Anatomy::UBERON:0001905', 'Anatomy'),
#  ('Anatomy::UBERON:0001908', 'Anatomy'),
#  ('Anatomy::UBERON:0001910', 'Anatomy'),
#  ('Anatomy::UBERON:0001911', 'Anatomy'),
#  ('Anatomy::UBERON:0001914', 'Anatomy'),
#  ('Anatomy::UBERON:0001968', 'Anatomy'),
#  ('Anatomy::UBERON:0001969', 'Anatomy'),
#  ('Anatomy::UBERON:0001970', 'Anatomy'),
#  ('Anatomy::UBERON:0001971', 'Anatomy'),
#  ('Anatomy::UBERON:0001980', 'Anatomy'),
#  ('Anatomy::UBERON:0001981', 'Anatomy'),
#  ('Anatomy::UBERON:0001985', 'Anatomy'),
#  ('Anatomy::UBERON:0001986', 'Anatomy'),
#  ('Anatomy::UBERON:0001988', 'Anatomy'),
#  ('Anatomy::UBERON:0001989', 'Anatomy'),
#  ('Anatomy::UBERON:0002005', 'Anatomy'),
#  ('Anatomy::UBERON:0002010', 'Anatomy'),
#  ('Anatomy::UBERON:0002012', 'Anatomy'),
#  ('Anatomy::UBERON:0002016', 'Anatomy'),
#  ('Anatomy::UBERON:0002017', 'Anatomy'),
#  ('Anatomy::UBERON:0002018', 'Anatomy'),
#  ('Anatomy::UBERON:0002019', 'Anatomy'),
#  ('Anatomy::UBERON:0002028', 'Anatomy'),
#  ('Anatomy::UBERON:0002030', 'Anatomy'),
#  ('Anatomy::UBERON:0002037', 'Anatomy'),
#  ('Anatomy::UBERON:0002040', 'Anatomy'),
#  ('Anatomy::UBERON:0002046', 'Anatomy'),
#  ('Anatomy::UBERON:0002048', 'Anatomy'),
#  ('Anatomy::UBERON:0002053', 'Anatomy'),
#  ('Anatomy::UBERON:0002054', 'Anatomy'),
#  ('Anatomy::UBERON:0002055', 'Anatomy'),
#  ('Anatomy::UBERON:0002060', 'Anatomy'),
#  ('Anatomy::UBERON:0002061', 'Anatomy'),
#  ('Anatomy::UBERON:0002066', 'Anatomy'),
#  ('Anatomy::UBERON:0002067', 'Anatomy'),
#  ('Anatomy::UBERON:0002073', 'Anatomy'),
#  ('Anatomy::UBERON:0002081', 'Anatomy'),
#  ('Anatomy::UBERON:0002082', 'Anatomy'),
#  ('Anatomy::UBERON:0002097', 'Anatomy'),
#  ('Anatomy::UBERON:0002099', 'Anatomy'),
#  ('Anatomy::UBERON:0002102', 'Anatomy'),
#  ('Anatomy::UBERON:0002103', 'Anatomy'),
#  ('Anatomy::UBERON:0002107', 'Anatomy'),
#  ('Anatomy::UBERON:0002110', 'Anatomy'),
#  ('Anatomy::UBERON:0002113', 'Anatomy'),
#  ('Anatomy::UBERON:0002129', 'Anatomy'),
#  ('Anatomy::UBERON:0002130', 'Anatomy'),
#  ('Anatomy::UBERON:0002134', 'Anatomy'),
#  ('Anatomy::UBERON:0002135', 'Anatomy'),
#  ('Anatomy::UBERON:0002137', 'Anatomy'),
#  ('Anatomy::UBERON:0002146', 'Anatomy'),
#  ('Anatomy::UBERON:0002148', 'Anatomy'),
#  ('Anatomy::UBERON:0002162', 'Anatomy'),
#  ('Anatomy::UBERON:0002165', 'Anatomy'),
#  ('Anatomy::UBERON:0002185', 'Anatomy'),
#  ('Anatomy::UBERON:0002204', 'Anatomy'),
#  ('Anatomy::UBERON:0002205', 'Anatomy'),
#  ('Anatomy::UBERON:0002223', 'Anatomy'),
#  ('Anatomy::UBERON:0002226', 'Anatomy'),
#  ('Anatomy::UBERON:0002228', 'Anatomy'),
#  ('Anatomy::UBERON:0002240', 'Anatomy'),
#  ('Anatomy::UBERON:0002250', 'Anatomy'),
#  ('Anatomy::UBERON:0002275', 'Anatomy'),
#  ('Anatomy::UBERON:0002279', 'Anatomy'),
#  ('Anatomy::UBERON:0002282', 'Anatomy'),
#  ('Anatomy::UBERON:0002285', 'Anatomy'),
#  ('Anatomy::UBERON:0002286', 'Anatomy'),
#  ('Anatomy::UBERON:0002294', 'Anatomy'),
#  ('Anatomy::UBERON:0002297', 'Anatomy'),
#  ('Anatomy::UBERON:0002298', 'Anatomy'),
#  ('Anatomy::UBERON:0002299', 'Anatomy'),
#  ('Anatomy::UBERON:0002303', 'Anatomy'),
#  ('Anatomy::UBERON:0002347', 'Anatomy'),
#  ('Anatomy::UBERON:0002349', 'Anatomy'),
#  ('Anatomy::UBERON:0002351', 'Anatomy'),
#  ('Anatomy::UBERON:0002352', 'Anatomy'),
#  ('Anatomy::UBERON:0002353', 'Anatomy'),
#  ('Anatomy::UBERON:0002354', 'Anatomy'),
#  ('Anatomy::UBERON:0002356', 'Anatomy'),
#  ('Anatomy::UBERON:0002360', 'Anatomy'),
#  ('Anatomy::UBERON:0002361', 'Anatomy'),
#  ('Anatomy::UBERON:0002362', 'Anatomy'),
#  ('Anatomy::UBERON:0002363', 'Anatomy'),
#  ('Anatomy::UBERON:0002365', 'Anatomy'),
#  ('Anatomy::UBERON:0002366', 'Anatomy'),
#  ('Anatomy::UBERON:0002367', 'Anatomy'),
#  ('Anatomy::UBERON:0002368', 'Anatomy'),
#  ('Anatomy::UBERON:0002369', 'Anatomy'),
#  ('Anatomy::UBERON:0002371', 'Anatomy'),
#  ('Anatomy::UBERON:0002377', 'Anatomy'),
#  ('Anatomy::UBERON:0002378', 'Anatomy'),
#  ('Anatomy::UBERON:0002382', 'Anatomy'),
#  ('Anatomy::UBERON:0002384', 'Anatomy'),
#  ('Anatomy::UBERON:0002385', 'Anatomy'),
#  ('Anatomy::UBERON:0002386', 'Anatomy'),
#  ('Anatomy::UBERON:0002387', 'Anatomy'),
#  ('Anatomy::UBERON:0002389', 'Anatomy'),
#  ('Anatomy::UBERON:0002390', 'Anatomy'),
#  ('Anatomy::UBERON:0002392', 'Anatomy'),
#  ('Anatomy::UBERON:0002394', 'Anatomy'),
#  ('Anatomy::UBERON:0002397', 'Anatomy'),
#  ('Anatomy::UBERON:0002398', 'Anatomy'),
#  ('Anatomy::UBERON:0002405', 'Anatomy'),
#  ('Anatomy::UBERON:0002407', 'Anatomy'),
#  ('Anatomy::UBERON:0002410', 'Anatomy'),
#  ('Anatomy::UBERON:0002411', 'Anatomy'),
#  ('Anatomy::UBERON:0002413', 'Anatomy'),
#  ('Anatomy::UBERON:0002414', 'Anatomy'),
#  ('Anatomy::UBERON:0002418', 'Anatomy'),
#  ('Anatomy::UBERON:0002422', 'Anatomy'),
#  ('Anatomy::UBERON:0002439', 'Anatomy'),
#  ('Anatomy::UBERON:0002441', 'Anatomy'),
#  ('Anatomy::UBERON:0002450', 'Anatomy'),
#  ('Anatomy::UBERON:0002453', 'Anatomy'),
#  ('Anatomy::UBERON:0002466', 'Anatomy'),
#  ('Anatomy::UBERON:0002481', 'Anatomy'),
#  ('Anatomy::UBERON:0002486', 'Anatomy'),
#  ('Anatomy::UBERON:0002494', 'Anatomy'),
#  ('Anatomy::UBERON:0002497', 'Anatomy'),
#  ('Anatomy::UBERON:0002500', 'Anatomy'),
#  ('Anatomy::UBERON:0002501', 'Anatomy'),
#  ('Anatomy::UBERON:0002502', 'Anatomy'),
#  ('Anatomy::UBERON:0002512', 'Anatomy'),
#  ('Anatomy::UBERON:0002515', 'Anatomy'),
#  ('Anatomy::UBERON:0002516', 'Anatomy'),
#  ('Anatomy::UBERON:0002517', 'Anatomy'),
#  ('Anatomy::UBERON:0002518', 'Anatomy'),
#  ('Anatomy::UBERON:0002519', 'Anatomy'),
#  ('Anatomy::UBERON:0002521', 'Anatomy'),
#  ('Anatomy::UBERON:0002522', 'Anatomy'),
#  ('Anatomy::UBERON:0002523', 'Anatomy'),
#  ('Anatomy::UBERON:0002606', 'Anatomy'),
#  ('Anatomy::UBERON:0002673', 'Anatomy'),
#  ('Anatomy::UBERON:0002707', 'Anatomy'),
#  ('Anatomy::UBERON:0002741', 'Anatomy'),
#  ('Anatomy::UBERON:0002925', 'Anatomy'),
#  ('Anatomy::UBERON:0002944', 'Anatomy'),
#  ('Anatomy::UBERON:0003092', 'Anatomy'),
#  ('Anatomy::UBERON:0003126', 'Anatomy'),
#  ('Anatomy::UBERON:0003129', 'Anatomy'),
#  ('Anatomy::UBERON:0003216', 'Anatomy'),
#  ('Anatomy::UBERON:0003685', 'Anatomy'),
#  ('Anatomy::UBERON:0003889', 'Anatomy'),
#  ('Anatomy::UBERON:0004288', 'Anatomy'),
#  ('Anatomy::UBERON:0004452', 'Anatomy'),
#  ('Anatomy::UBERON:0004535', 'Anatomy'),
#  ('Anatomy::UBERON:0004727', 'Anatomy'),
#  ('Anatomy::UBERON:0004769', 'Anatomy'),
#  ('Anatomy::UBERON:0006849', 'Anatomy'),
#  ('Biological Process::GO:0000002', 'Biological Process'),
#  ('Biological Process::GO:0000012', 'Biological Process'),
#  ('Biological Process::GO:0000018', 'Biological Process'),
#  ('Biological Process::GO:0000019', 'Biological Process'),
#  ('Biological Process::GO:0000022', 'Biological Process'),
#  ('Biological Process::GO:0000023', 'Biological Process'),
#  ('Biological Process::GO:0000027', 'Biological Process'),
#  ('Biological Process::GO:0000028', 'Biological Process'),
#  ('Biological Process::GO:0000032', 'Biological Process'),
#  ('Biological Process::GO:0000038', 'Biological Process'),
#  ('Biological Process::GO:0000041', 'Biological Process'),
#  ('Biological Process::GO:0000042', 'Biological Process'),
#  ('Biological Process::GO:0000045', 'Biological Process'),
#  ('Biological Process::GO:0000050', 'Biological Process'),
#  ('Biological Process::GO:0000052', 'Biological Process'),
#  ('Biological Process::GO:0000054', 'Biological Process'),
#  ('Biological Process::GO:0000055', 'Biological Process'),
#  ('Biological Process::GO:0000056', 'Biological Process'),
#  ('Biological Process::GO:0000059', 'Biological Process'),
#  ('Biological Process::GO:0000060', 'Biological Process'),
#  ('Biological Process::GO:0000070', 'Biological Process'),
#  ('Biological Process::GO:0000075', 'Biological Process'),
#  ('Biological Process::GO:0000076', 'Biological Process'),
#  ('Biological Process::GO:0000077', 'Biological Process'),
#  ('Biological Process::GO:0000079', 'Biological Process'),
#  ('Biological Process::GO:0000082', 'Biological Process'),
#  ('Biological Process::GO:0000083', 'Biological Process'),
#  ('Biological Process::GO:0000086', 'Biological Process'),
#  ('Biological Process::GO:0000096', 'Biological Process'),
#  ('Biological Process::GO:0000097', 'Biological Process'),
#  ('Biological Process::GO:0000098', 'Biological Process'),
#  ('Biological Process::GO:0000101', 'Biological Process'),
#  ('Biological Process::GO:0000103', 'Biological Process'),
#  ('Biological Process::GO:0000105', 'Biological Process'),
#  ('Biological Process::GO:0000122', 'Biological Process'),
#  ('Biological Process::GO:0000132', 'Biological Process'),
#  ('Biological Process::GO:0000154', 'Biological Process'),
#  ('Biological Process::GO:0000160', 'Biological Process'),
#  ('Biological Process::GO:0000165', 'Biological Process'),
#  ('Biological Process::GO:0000183', 'Biological Process'),
#  ('Biological Process::GO:0000184', 'Biological Process'),
#  ('Biological Process::GO:0000185', 'Biological Process'),
#  ('Biological Process::GO:0000186', 'Biological Process'),
#  ('Biological Process::GO:0000187', 'Biological Process'),
#  ('Biological Process::GO:0000188', 'Biological Process'),
#  ('Biological Process::GO:0000189', 'Biological Process'),
#  ('Biological Process::GO:0000209', 'Biological Process'),
#  ('Biological Process::GO:0000212', 'Biological Process'),
#  ('Biological Process::GO:0000226', 'Biological Process'),
#  ('Biological Process::GO:0000244', 'Biological Process'),
#  ('Biological Process::GO:0000245', 'Biological Process'),
#  ('Biological Process::GO:0000255', 'Biological Process'),
#  ('Biological Process::GO:0000266', 'Biological Process'),
#  ('Biological Process::GO:0000270', 'Biological Process'),
#  ('Biological Process::GO:0000271', 'Biological Process'),
#  ('Biological Process::GO:0000272', 'Biological Process'),
#  ('Biological Process::GO:0000278', 'Biological Process'),
#  ('Biological Process::GO:0000280', 'Biological Process'),
#  ('Biological Process::GO:0000281', 'Biological Process'),
#  ('Biological Process::GO:0000288', 'Biological Process'),
#  ('Biological Process::GO:0000289', 'Biological Process'),
#  ('Biological Process::GO:0000290', 'Biological Process'),
#  ('Biological Process::GO:0000291', 'Biological Process'),
#  ('Biological Process::GO:0000294', 'Biological Process'),
#  ('Biological Process::GO:0000301', 'Biological Process'),
#  ('Biological Process::GO:0000302', 'Biological Process'),
#  ('Biological Process::GO:0000303', 'Biological Process'),
#  ('Biological Process::GO:0000305', 'Biological Process'),
#  ('Biological Process::GO:0000320', 'Biological Process'),
#  ('Biological Process::GO:0000338', 'Biological Process'),
#  ('Biological Process::GO:0000350', 'Biological Process'),
#  ('Biological Process::GO:0000354', 'Biological Process'),
#  ('Biological Process::GO:0000375', 'Biological Process'),
#  ('Biological Process::GO:0000377', 'Biological Process'),
#  ('Biological Process::GO:0000379', 'Biological Process'),
#  ('Biological Process::GO:0000380', 'Biological Process'),
#  ('Biological Process::GO:0000381', 'Biological Process'),
#  ('Biological Process::GO:0000387', 'Biological Process'),
#  ('Biological Process::GO:0000389', 'Biological Process'),
#  ('Biological Process::GO:0000393', 'Biological Process'),
#  ('Biological Process::GO:0000394', 'Biological Process'),
#  ('Biological Process::GO:0000395', 'Biological Process'),
#  ('Biological Process::GO:0000398', 'Biological Process'),
#  ('Biological Process::GO:0000413', 'Biological Process'),
#  ('Biological Process::GO:0000414', 'Biological Process'),
#  ('Biological Process::GO:0000422', 'Biological Process'),
#  ('Biological Process::GO:0000423', 'Biological Process'),
#  ('Biological Process::GO:0000429', 'Biological Process'),
#  ('Biological Process::GO:0000430', 'Biological Process'),
#  ('Biological Process::GO:0000432', 'Biological Process'),
#  ('Biological Process::GO:0000436', 'Biological Process'),
#  ('Biological Process::GO:0000447', 'Biological Process'),
#  ('Biological Process::GO:0000448', 'Biological Process'),
#  ('Biological Process::GO:0000451', 'Biological Process'),
#  ('Biological Process::GO:0000453', 'Biological Process'),
#  ('Biological Process::GO:0000459', 'Biological Process'),
#  ('Biological Process::GO:0000460', 'Biological Process'),
#  ('Biological Process::GO:0000461', 'Biological Process'),
#  ('Biological Process::GO:0000462', 'Biological Process'),
#  ('Biological Process::GO:0000463', 'Biological Process'),
#  ('Biological Process::GO:0000466', 'Biological Process'),
#  ('Biological Process::GO:0000467', 'Biological Process'),
#  ('Biological Process::GO:0000469', 'Biological Process'),
#  ('Biological Process::GO:0000470', 'Biological Process'),
#  ('Biological Process::GO:0000472', 'Biological Process'),
#  ('Biological Process::GO:0000478', 'Biological Process'),
#  ('Biological Process::GO:0000479', 'Biological Process'),
#  ('Biological Process::GO:0000480', 'Biological Process'),
#  ('Biological Process::GO:0000491', 'Biological Process'),
#  ('Biological Process::GO:0000492', 'Biological Process'),
#  ('Biological Process::GO:0000578', 'Biological Process'),
#  ('Biological Process::GO:0000707', 'Biological Process'),
#  ('Biological Process::GO:0000711', 'Biological Process'),
#  ('Biological Process::GO:0000712', 'Biological Process'),
#  ('Biological Process::GO:0000715', 'Biological Process'),
#  ('Biological Process::GO:0000720', 'Biological Process'),
#  ('Biological Process::GO:0000722', 'Biological Process'),
#  ('Biological Process::GO:0000723', 'Biological Process'),
#  ('Biological Process::GO:0000724', 'Biological Process'),
#  ('Biological Process::GO:0000725', 'Biological Process'),
#  ('Biological Process::GO:0000726', 'Biological Process'),
#  ('Biological Process::GO:0000727', 'Biological Process'),
#  ('Biological Process::GO:0000729', 'Biological Process'),
#  ('Biological Process::GO:0000730', 'Biological Process'),
#  ('Biological Process::GO:0000731', 'Biological Process'),
#  ('Biological Process::GO:0000733', 'Biological Process'),
#  ('Biological Process::GO:0000737', 'Biological Process'),
#  ('Biological Process::GO:0000738', 'Biological Process'),
#  ('Biological Process::GO:0000768', 'Biological Process'),
#  ('Biological Process::GO:0000819', 'Biological Process'),
#  ('Biological Process::GO:0000820', 'Biological Process'),
#  ('Biological Process::GO:0000821', 'Biological Process'),
#  ('Biological Process::GO:0000904', 'Biological Process'),
#  ('Biological Process::GO:0000910', 'Biological Process'),
#  ('Biological Process::GO:0000917', 'Biological Process'),
#  ('Biological Process::GO:0000920', 'Biological Process'),
#  ('Biological Process::GO:0000956', 'Biological Process'),
#  ('Biological Process::GO:0000957', 'Biological Process'),
#  ('Biological Process::GO:0000958', 'Biological Process'),
#  ('Biological Process::GO:0000959', 'Biological Process'),
#  ('Biological Process::GO:0000960', 'Biological Process'),
#  ('Biological Process::GO:0000961', 'Biological Process'),
#  ('Biological Process::GO:0000962', 'Biological Process'),
#  ('Biological Process::GO:0000963', 'Biological Process'),
#  ('Biological Process::GO:0000964', 'Biological Process'),
#  ('Biological Process::GO:0000965', 'Biological Process'),
#  ('Biological Process::GO:0000966', 'Biological Process'),
#  ('Biological Process::GO:0000967', 'Biological Process'),
#  ('Biological Process::GO:0000972', 'Biological Process'),
#  ('Biological Process::GO:0000973', 'Biological Process'),
#  ('Biological Process::GO:0001101', 'Biological Process'),
#  ('Biological Process::GO:0001172', 'Biological Process'),
#  ('Biological Process::GO:0001180', 'Biological Process'),
#  ('Biological Process::GO:0001188', 'Biological Process'),
#  ('Biological Process::GO:0001189', 'Biological Process'),
#  ('Biological Process::GO:0001300', 'Biological Process'),
#  ('Biological Process::GO:0001302', 'Biological Process'),
#  ('Biological Process::GO:0001306', 'Biological Process'),
#  ('Biological Process::GO:0001501', 'Biological Process'),
#  ('Biological Process::GO:0001502', 'Biological Process'),
#  ('Biological Process::GO:0001503', 'Biological Process'),
#  ('Biological Process::GO:0001504', 'Biological Process'),
#  ('Biological Process::GO:0001505', 'Biological Process'),
#  ('Biological Process::GO:0001507', 'Biological Process'),
#  ('Biological Process::GO:0001508', 'Biological Process'),
#  ('Biological Process::GO:0001510', 'Biological Process'),
#  ('Biological Process::GO:0001514', 'Biological Process'),
#  ('Biological Process::GO:0001516', 'Biological Process'),
#  ('Biological Process::GO:0001519', 'Biological Process'),
#  ('Biological Process::GO:0001522', 'Biological Process'),
#  ('Biological Process::GO:0001523', 'Biological Process'),
#  ('Biological Process::GO:0001525', 'Biological Process'),
#  ('Biological Process::GO:0001539', 'Biological Process'),
#  ('Biological Process::GO:0001541', 'Biological Process'),
#  ('Biological Process::GO:0001542', 'Biological Process'),
#  ('Biological Process::GO:0001543', 'Biological Process'),
#  ('Biological Process::GO:0001546', 'Biological Process'),
#  ('Biological Process::GO:0001547', 'Biological Process'),
#  ('Biological Process::GO:0001550', 'Biological Process'),
#  ('Biological Process::GO:0001552', 'Biological Process'),
#  ('Biological Process::GO:0001553', 'Biological Process'),
#  ('Biological Process::GO:0001554', 'Biological Process'),
#  ('Biological Process::GO:0001555', 'Biological Process'),
#  ('Biological Process::GO:0001556', 'Biological Process'),
#  ('Biological Process::GO:0001558', 'Biological Process'),
#  ('Biological Process::GO:0001560', 'Biological Process'),
#  ('Biological Process::GO:0001561', 'Biological Process'),
#  ('Biological Process::GO:0001562', 'Biological Process'),
#  ('Biological Process::GO:0001568', 'Biological Process'),
#  ('Biological Process::GO:0001569', 'Biological Process'),
#  ('Biological Process::GO:0001570', 'Biological Process'),
#  ('Biological Process::GO:0001573', 'Biological Process'),
#  ('Biological Process::GO:0001574', 'Biological Process'),
#  ('Biological Process::GO:0001575', 'Biological Process'),
#  ('Biological Process::GO:0001578', 'Biological Process'),
#  ('Biological Process::GO:0001579', 'Biological Process'),
#  ('Biological Process::GO:0001580', 'Biological Process'),
#  ('Biological Process::GO:0001581', 'Biological Process'),
#  ('Biological Process::GO:0001582', 'Biological Process'),
#  ('Biological Process::GO:0001649', 'Biological Process'),
#  ('Biological Process::GO:0001654', 'Biological Process'),
#  ('Biological Process::GO:0001655', 'Biological Process'),
#  ('Biological Process::GO:0001656', 'Biological Process'),
#  ('Biological Process::GO:0001657', 'Biological Process'),
#  ('Biological Process::GO:0001658', 'Biological Process'),
#  ('Biological Process::GO:0001659', 'Biological Process'),
#  ('Biological Process::GO:0001660', 'Biological Process'),
#  ('Biological Process::GO:0001661', 'Biological Process'),
#  ('Biological Process::GO:0001662', 'Biological Process'),
#  ('Biological Process::GO:0001666', 'Biological Process'),
#  ('Biological Process::GO:0001667', 'Biological Process'),
#  ('Biological Process::GO:0001672', 'Biological Process'),
#  ('Biological Process::GO:0001675', 'Biological Process'),
#  ('Biological Process::GO:0001676', 'Biological Process'),
#  ('Biological Process::GO:0001678', 'Biological Process'),
#  ('Biological Process::GO:0001692', 'Biological Process'),
#  ('Biological Process::GO:0001694', 'Biological Process'),
#  ('Biological Process::GO:0001696', 'Biological Process'),
#  ('Biological Process::GO:0001701', 'Biological Process'),
#  ('Biological Process::GO:0001702', 'Biological Process'),
#  ('Biological Process::GO:0001704', 'Biological Process'),
#  ('Biological Process::GO:0001705', 'Biological Process'),
#  ('Biological Process::GO:0001706', 'Biological Process'),
#  ('Biological Process::GO:0001707', 'Biological Process'),
#  ('Biological Process::GO:0001708', 'Biological Process'),
#  ('Biological Process::GO:0001709', 'Biological Process'),
#  ('Biological Process::GO:0001710', 'Biological Process'),
#  ('Biological Process::GO:0001711', 'Biological Process'),
#  ('Biological Process::GO:0001712', 'Biological Process'),
#  ('Biological Process::GO:0001714', 'Biological Process'),
#  ('Biological Process::GO:0001731', 'Biological Process'),
#  ('Biological Process::GO:0001732', 'Biological Process'),
#  ('Biological Process::GO:0001736', 'Biological Process'),
#  ('Biological Process::GO:0001738', 'Biological Process'),
#  ('Biological Process::GO:0001743', 'Biological Process'),
#  ('Biological Process::GO:0001754', 'Biological Process'),
#  ('Biological Process::GO:0001755', 'Biological Process'),
#  ('Biological Process::GO:0001756', 'Biological Process'),
#  ('Biological Process::GO:0001757', 'Biological Process'),
#  ('Biological Process::GO:0001759', 'Biological Process'),
#  ('Biological Process::GO:0001763', 'Biological Process'),
#  ('Biological Process::GO:0001764', 'Biological Process'),
#  ('Biological Process::GO:0001765', 'Biological Process'),
#  ('Biological Process::GO:0001766', 'Biological Process'),
#  ('Biological Process::GO:0001767', 'Biological Process'),
#  ('Biological Process::GO:0001768', 'Biological Process'),
#  ('Biological Process::GO:0001771', 'Biological Process'),
#  ('Biological Process::GO:0001773', 'Biological Process'),
#  ('Biological Process::GO:0001774', 'Biological Process'),
#  ('Biological Process::GO:0001775', 'Biological Process'),
#  ('Biological Process::GO:0001776', 'Biological Process'),
#  ('Biological Process::GO:0001778', 'Biological Process'),
#  ('Biological Process::GO:0001779', 'Biological Process'),
#  ('Biological Process::GO:0001780', 'Biological Process'),
#  ('Biological Process::GO:0001781', 'Biological Process'),
#  ('Biological Process::GO:0001782', 'Biological Process'),
#  ('Biological Process::GO:0001783', 'Biological Process'),
#  ('Biological Process::GO:0001796', 'Biological Process'),
#  ('Biological Process::GO:0001798', 'Biological Process'),
#  ('Biological Process::GO:0001807', 'Biological Process'),
#  ('Biological Process::GO:0001808', 'Biological Process'),
#  ('Biological Process::GO:0001810', 'Biological Process'),
#  ('Biological Process::GO:0001812', 'Biological Process'),
#  ('Biological Process::GO:0001816', 'Biological Process'),
#  ('Biological Process::GO:0001817', 'Biological Process'),
#  ('Biological Process::GO:0001818', 'Biological Process'),
#  ('Biological Process::GO:0001819', 'Biological Process'),
#  ('Biological Process::GO:0001820', 'Biological Process'),
#  ('Biological Process::GO:0001821', 'Biological Process'),
#  ('Biological Process::GO:0001822', 'Biological Process'),
#  ('Biological Process::GO:0001823', 'Biological Process'),
#  ('Biological Process::GO:0001824', 'Biological Process'),
#  ('Biological Process::GO:0001825', 'Biological Process'),
#  ('Biological Process::GO:0001826', 'Biological Process'),
#  ('Biological Process::GO:0001827', 'Biological Process'),
#  ('Biological Process::GO:0001828', 'Biological Process'),
#  ('Biological Process::GO:0001829', 'Biological Process'),
#  ('Biological Process::GO:0001831', 'Biological Process'),
#  ('Biological Process::GO:0001832', 'Biological Process'),
#  ('Biological Process::GO:0001833', 'Biological Process'),
#  ('Biological Process::GO:0001834', 'Biological Process'),
#  ('Biological Process::GO:0001835', 'Biological Process'),
#  ('Biological Process::GO:0001836', 'Biological Process'),
#  ('Biological Process::GO:0001837', 'Biological Process'),
#  ('Biological Process::GO:0001838', 'Biological Process'),
#  ('Biological Process::GO:0001839', 'Biological Process'),
#  ('Biological Process::GO:0001840', 'Biological Process'),
#  ('Biological Process::GO:0001841', 'Biological Process'),
#  ('Biological Process::GO:0001842', 'Biological Process'),
#  ('Biological Process::GO:0001843', 'Biological Process'),
#  ('Biological Process::GO:0001844', 'Biological Process'),
#  ('Biological Process::GO:0001845', 'Biological Process'),
#  ('Biological Process::GO:0001865', 'Biological Process'),
#  ('Biological Process::GO:0001866', 'Biological Process'),
#  ('Biological Process::GO:0001867', 'Biological Process'),
#  ('Biological Process::GO:0001868', 'Biological Process'),
#  ('Biological Process::GO:0001869', 'Biological Process'),
#  ('Biological Process::GO:0001878', 'Biological Process'),
#  ('Biological Process::GO:0001880', 'Biological Process'),
#  ('Biological Process::GO:0001881', 'Biological Process'),
#  ('Biological Process::GO:0001885', 'Biological Process'),
#  ('Biological Process::GO:0001886', 'Biological Process'),
#  ('Biological Process::GO:0001887', 'Biological Process'),
#  ('Biological Process::GO:0001889', 'Biological Process'),
#  ('Biological Process::GO:0001890', 'Biological Process'),
#  ('Biological Process::GO:0001892', 'Biological Process'),
#  ('Biological Process::GO:0001893', 'Biological Process'),
#  ('Biological Process::GO:0001894', 'Biological Process'),
#  ('Biological Process::GO:0001895', 'Biological Process'),
#  ('Biological Process::GO:0001897', 'Biological Process'),
#  ('Biological Process::GO:0001906', 'Biological Process'),
#  ('Biological Process::GO:0001907', 'Biological Process'),
#  ('Biological Process::GO:0001909', 'Biological Process'),
#  ('Biological Process::GO:0001910', 'Biological Process'),
#  ('Biological Process::GO:0001911', 'Biological Process'),
#  ('Biological Process::GO:0001912', 'Biological Process'),
#  ('Biological Process::GO:0001913', 'Biological Process'),
#  ('Biological Process::GO:0001914', 'Biological Process'),
#  ('Biological Process::GO:0001915', 'Biological Process'),
#  ('Biological Process::GO:0001916', 'Biological Process'),
#  ('Biological Process::GO:0001919', 'Biological Process'),
#  ('Biological Process::GO:0001920', 'Biological Process'),
#  ('Biological Process::GO:0001921', 'Biological Process'),
#  ('Biological Process::GO:0001922', 'Biological Process'),
#  ('Biological Process::GO:0001923', 'Biological Process'),
#  ('Biological Process::GO:0001927', 'Biological Process'),
#  ('Biological Process::GO:0001933', 'Biological Process'),
#  ('Biological Process::GO:0001934', 'Biological Process'),
#  ('Biological Process::GO:0001935', 'Biological Process'),
#  ('Biological Process::GO:0001936', 'Biological Process'),
#  ('Biological Process::GO:0001937', 'Biological Process'),
#  ('Biological Process::GO:0001938', 'Biological Process'),
#  ('Biological Process::GO:0001941', 'Biological Process'),
#  ('Biological Process::GO:0001942', 'Biological Process'),
#  ('Biological Process::GO:0001944', 'Biological Process'),
#  ('Biological Process::GO:0001945', 'Biological Process'),
#  ('Biological Process::GO:0001946', 'Biological Process'),
#  ('Biological Process::GO:0001947', 'Biological Process'),
#  ('Biological Process::GO:0001951', 'Biological Process'),
#  ('Biological Process::GO:0001952', 'Biological Process'),
#  ('Biological Process::GO:0001953', 'Biological Process'),
#  ('Biological Process::GO:0001954', 'Biological Process'),
#  ('Biological Process::GO:0001955', 'Biological Process'),
#  ('Biological Process::GO:0001956', 'Biological Process'),
#  ('Biological Process::GO:0001957', 'Biological Process'),
#  ('Biological Process::GO:0001958', 'Biological Process'),
#  ('Biological Process::GO:0001959', 'Biological Process'),
#  ('Biological Process::GO:0001960', 'Biological Process'),
#  ('Biological Process::GO:0001961', 'Biological Process'),
#  ('Biological Process::GO:0001963', 'Biological Process'),
#  ('Biological Process::GO:0001964', 'Biological Process'),
#  ('Biological Process::GO:0001967', 'Biological Process'),
#  ('Biological Process::GO:0001969', 'Biological Process'),
#  ('Biological Process::GO:0001970', 'Biological Process'),
#  ('Biological Process::GO:0001973', 'Biological Process'),
#  ('Biological Process::GO:0001974', 'Biological Process'),
#  ('Biological Process::GO:0001975', 'Biological Process'),
#  ('Biological Process::GO:0001976', 'Biological Process'),
#  ('Biological Process::GO:0001977', 'Biological Process'),
#  ('Biological Process::GO:0001978', 'Biological Process'),
#  ('Biological Process::GO:0001982', 'Biological Process'),
#  ('Biological Process::GO:0001983', 'Biological Process'),
#  ('Biological Process::GO:0001990', 'Biological Process'),
#  ('Biological Process::GO:0001991', 'Biological Process'),
#  ('Biological Process::GO:0001992', 'Biological Process'),
#  ('Biological Process::GO:0001993', 'Biological Process'),
#  ('Biological Process::GO:0001994', 'Biological Process'),
#  ('Biological Process::GO:0001996', 'Biological Process'),
#  ('Biological Process::GO:0001997', 'Biological Process'),
#  ('Biological Process::GO:0001999', 'Biological Process'),
#  ('Biological Process::GO:0002002', 'Biological Process'),
#  ('Biological Process::GO:0002003', 'Biological Process'),
#  ('Biological Process::GO:0002005', 'Biological Process'),
#  ('Biological Process::GO:0002009', 'Biological Process'),
#  ('Biological Process::GO:0002011', 'Biological Process'),
#  ('Biological Process::GO:0002016', 'Biological Process'),
#  ('Biological Process::GO:0002017', 'Biological Process'),
#  ('Biological Process::GO:0002018', 'Biological Process'),
#  ('Biological Process::GO:0002019', 'Biological Process'),
#  ('Biological Process::GO:0002021', 'Biological Process'),
#  ('Biological Process::GO:0002023', 'Biological Process'),
#  ('Biological Process::GO:0002024', 'Biological Process'),
#  ('Biological Process::GO:0002025', 'Biological Process'),
#  ('Biological Process::GO:0002026', 'Biological Process'),
#  ('Biological Process::GO:0002027', 'Biological Process'),
#  ('Biological Process::GO:0002028', 'Biological Process'),
#  ('Biological Process::GO:0002029', 'Biological Process'),
#  ('Biological Process::GO:0002031', 'Biological Process'),
#  ('Biological Process::GO:0002032', 'Biological Process'),
#  ('Biological Process::GO:0002034', 'Biological Process'),
#  ('Biological Process::GO:0002035', 'Biological Process'),
#  ('Biological Process::GO:0002036', 'Biological Process'),
#  ('Biological Process::GO:0002040', 'Biological Process'),
#  ('Biological Process::GO:0002041', 'Biological Process'),
#  ('Biological Process::GO:0002042', 'Biological Process'),
#  ('Biological Process::GO:0002043', 'Biological Process'),
#  ('Biological Process::GO:0002051', 'Biological Process'),
#  ('Biological Process::GO:0002052', 'Biological Process'),
#  ('Biological Process::GO:0002053', 'Biological Process'),
#  ('Biological Process::GO:0002062', 'Biological Process'),
#  ('Biological Process::GO:0002063', 'Biological Process'),
#  ('Biological Process::GO:0002064', 'Biological Process'),
#  ('Biological Process::GO:0002065', 'Biological Process'),
#  ('Biological Process::GO:0002066', 'Biological Process'),
#  ('Biological Process::GO:0002067', 'Biological Process'),
#  ('Biological Process::GO:0002068', 'Biological Process'),
#  ('Biological Process::GO:0002069', 'Biological Process'),
#  ('Biological Process::GO:0002070', 'Biological Process'),
#  ('Biological Process::GO:0002071', 'Biological Process'),
#  ('Biological Process::GO:0002072', 'Biological Process'),
#  ('Biological Process::GO:0002074', 'Biological Process'),
#  ('Biological Process::GO:0002076', 'Biological Process'),
#  ('Biological Process::GO:0002082', 'Biological Process'),
#  ('Biological Process::GO:0002084', 'Biological Process'),
#  ('Biological Process::GO:0002085', 'Biological Process'),
#  ('Biological Process::GO:0002086', 'Biological Process'),
#  ('Biological Process::GO:0002087', 'Biological Process'),
#  ('Biological Process::GO:0002088', 'Biological Process'),
#  ('Biological Process::GO:0002089', 'Biological Process'),
#  ('Biological Process::GO:0002090', 'Biological Process'),
#  ('Biological Process::GO:0002091', 'Biological Process'),
#  ('Biological Process::GO:0002092', 'Biological Process'),
#  ('Biological Process::GO:0002093', 'Biological Process'),
#  ('Biological Process::GO:0002097', 'Biological Process'),
#  ('Biological Process::GO:0002098', 'Biological Process'),
#  ('Biological Process::GO:0002115', 'Biological Process'),
#  ('Biological Process::GO:0002118', 'Biological Process'),
#  ('Biological Process::GO:0002121', 'Biological Process'),
#  ('Biological Process::GO:0002125', 'Biological Process'),
#  ('Biological Process::GO:0002138', 'Biological Process'),
#  ('Biological Process::GO:0002143', 'Biological Process'),
#  ('Biological Process::GO:0002155', 'Biological Process'),
#  ('Biological Process::GO:0002158', 'Biological Process'),
#  ('Biological Process::GO:0002159', 'Biological Process'),
#  ('Biological Process::GO:0002175', 'Biological Process'),
#  ('Biological Process::GO:0002176', 'Biological Process'),
#  ('Biological Process::GO:0002181', 'Biological Process'),
#  ('Biological Process::GO:0002183', 'Biological Process'),
#  ('Biological Process::GO:0002184', 'Biological Process'),
#  ('Biological Process::GO:0002190', 'Biological Process'),
#  ('Biological Process::GO:0002192', 'Biological Process'),
#  ('Biological Process::GO:0002200', 'Biological Process'),
#  ('Biological Process::GO:0002204', 'Biological Process'),
#  ('Biological Process::GO:0002208', 'Biological Process'),
#  ('Biological Process::GO:0002209', 'Biological Process'),
#  ('Biological Process::GO:0002215', 'Biological Process'),
#  ('Biological Process::GO:0002218', 'Biological Process'),
#  ('Biological Process::GO:0002220', 'Biological Process'),
#  ('Biological Process::GO:0002221', 'Biological Process'),
#  ('Biological Process::GO:0002223', 'Biological Process'),
#  ('Biological Process::GO:0002224', 'Biological Process'),
#  ('Biological Process::GO:0002225', 'Biological Process'),
#  ('Biological Process::GO:0002227', 'Biological Process'),
#  ('Biological Process::GO:0002228', 'Biological Process'),
#  ('Biological Process::GO:0002230', 'Biological Process'),
#  ('Biological Process::GO:0002232', 'Biological Process'),
#  ('Biological Process::GO:0002237', 'Biological Process'),
#  ('Biological Process::GO:0002238', 'Biological Process'),
#  ('Biological Process::GO:0002244', 'Biological Process'),
#  ('Biological Process::GO:0002246', 'Biological Process'),
#  ('Biological Process::GO:0002248', 'Biological Process'),
#  ('Biological Process::GO:0002250', 'Biological Process'),
#  ('Biological Process::GO:0002251', 'Biological Process'),
#  ('Biological Process::GO:0002252', 'Biological Process'),
#  ('Biological Process::GO:0002253', 'Biological Process'),
#  ('Biological Process::GO:0002254', 'Biological Process'),
#  ('Biological Process::GO:0002260', 'Biological Process'),
#  ('Biological Process::GO:0002262', 'Biological Process'),
#  ('Biological Process::GO:0002263', 'Biological Process'),
#  ('Biological Process::GO:0002266', 'Biological Process'),
#  ('Biological Process::GO:0002268', 'Biological Process'),
#  ('Biological Process::GO:0002274', 'Biological Process'),
#  ('Biological Process::GO:0002275', 'Biological Process'),
#  ('Biological Process::GO:0002277', 'Biological Process'),
#  ('Biological Process::GO:0002278', 'Biological Process'),
#  ('Biological Process::GO:0002279', 'Biological Process'),
#  ('Biological Process::GO:0002281', 'Biological Process'),
#  ('Biological Process::GO:0002282', 'Biological Process'),
#  ('Biological Process::GO:0002283', 'Biological Process'),
#  ('Biological Process::GO:0002285', 'Biological Process'),
#  ('Biological Process::GO:0002286', 'Biological Process'),
#  ('Biological Process::GO:0002287', 'Biological Process'),
#  ('Biological Process::GO:0002291', 'Biological Process'),
#  ('Biological Process::GO:0002292', 'Biological Process'),
#  ('Biological Process::GO:0002293', 'Biological Process'),
#  ('Biological Process::GO:0002294', 'Biological Process'),
#  ('Biological Process::GO:0002295', 'Biological Process'),
#  ('Biological Process::GO:0002296', 'Biological Process'),
#  ('Biological Process::GO:0002302', 'Biological Process'),
#  ('Biological Process::GO:0002309', 'Biological Process'),
#  ('Biological Process::GO:0002312', 'Biological Process'),
#  ('Biological Process::GO:0002313', 'Biological Process'),
#  ('Biological Process::GO:0002314', 'Biological Process'),
#  ('Biological Process::GO:0002315', 'Biological Process'),
#  ('Biological Process::GO:0002317', 'Biological Process'),
#  ('Biological Process::GO:0002318', 'Biological Process'),
#  ('Biological Process::GO:0002320', 'Biological Process'),
#  ('Biological Process::GO:0002322', 'Biological Process'),
#  ('Biological Process::GO:0002323', 'Biological Process'),
#  ('Biological Process::GO:0002326', 'Biological Process'),
#  ('Biological Process::GO:0002327', 'Biological Process'),
#  ('Biological Process::GO:0002328', 'Biological Process'),
#  ('Biological Process::GO:0002329', 'Biological Process'),
#  ('Biological Process::GO:0002331', 'Biological Process'),
#  ('Biological Process::GO:0002335', 'Biological Process'),
#  ('Biological Process::GO:0002337', 'Biological Process'),
#  ('Biological Process::GO:0002339', 'Biological Process'),
#  ('Biological Process::GO:0002347', 'Biological Process'),
#  ('Biological Process::GO:0002349', 'Biological Process'),
#  ('Biological Process::GO:0002351', 'Biological Process'),
#  ('Biological Process::GO:0002352', 'Biological Process'),
#  ('Biological Process::GO:0002353', 'Biological Process'),
#  ('Biological Process::GO:0002357', 'Biological Process'),
#  ('Biological Process::GO:0002358', 'Biological Process'),
#  ('Biological Process::GO:0002360', 'Biological Process'),
#  ('Biological Process::GO:0002361', 'Biological Process'),
#  ('Biological Process::GO:0002363', 'Biological Process'),
#  ('Biological Process::GO:0002366', 'Biological Process'),
#  ('Biological Process::GO:0002367', 'Biological Process'),
#  ('Biological Process::GO:0002369', 'Biological Process'),
#  ('Biological Process::GO:0002374', 'Biological Process'),
#  ('Biological Process::GO:0002377', 'Biological Process'),
#  ('Biological Process::GO:0002378', 'Biological Process'),
#  ('Biological Process::GO:0002381', 'Biological Process'),
#  ('Biological Process::GO:0002384', 'Biological Process'),
#  ('Biological Process::GO:0002385', 'Biological Process'),
#  ('Biological Process::GO:0002386', 'Biological Process'),
#  ('Biological Process::GO:0002396', 'Biological Process'),
#  ('Biological Process::GO:0002399', 'Biological Process'),
#  ('Biological Process::GO:0002407', 'Biological Process'),
#  ('Biological Process::GO:0002408', 'Biological Process'),
#  ('Biological Process::GO:0002414', 'Biological Process'),
#  ('Biological Process::GO:0002415', 'Biological Process'),
#  ('Biological Process::GO:0002418', 'Biological Process'),
#  ('Biological Process::GO:0002426', 'Biological Process'),
#  ('Biological Process::GO:0002428', 'Biological Process'),
#  ('Biological Process::GO:0002429', 'Biological Process'),
#  ('Biological Process::GO:0002430', 'Biological Process'),
#  ('Biological Process::GO:0002431', 'Biological Process'),
#  ('Biological Process::GO:0002432', 'Biological Process'),
#  ('Biological Process::GO:0002433', 'Biological Process'),
#  ('Biological Process::GO:0002437', 'Biological Process'),
#  ('Biological Process::GO:0002438', 'Biological Process'),
#  ('Biological Process::GO:0002439', 'Biological Process'),
#  ('Biological Process::GO:0002440', 'Biological Process'),
#  ('Biological Process::GO:0002441', 'Biological Process'),
#  ('Biological Process::GO:0002442', 'Biological Process'),
#  ('Biological Process::GO:0002443', 'Biological Process'),
#  ('Biological Process::GO:0002444', 'Biological Process'),
#  ('Biological Process::GO:0002446', 'Biological Process'),
#  ('Biological Process::GO:0002447', 'Biological Process'),
#  ('Biological Process::GO:0002448', 'Biological Process'),
#  ('Biological Process::GO:0002449', 'Biological Process'),
#  ('Biological Process::GO:0002455', 'Biological Process'),
#  ('Biological Process::GO:0002456', 'Biological Process'),
#  ('Biological Process::GO:0002457', 'Biological Process'),
#  ('Biological Process::GO:0002460', 'Biological Process'),
#  ('Biological Process::GO:0002467', 'Biological Process'),
#  ('Biological Process::GO:0002474', 'Biological Process'),
#  ('Biological Process::GO:0002475', 'Biological Process'),
#  ('Biological Process::GO:0002476', 'Biological Process'),
#  ('Biological Process::GO:0002477', 'Biological Process'),
#  ('Biological Process::GO:0002478', 'Biological Process'),
#  ('Biological Process::GO:0002479', 'Biological Process'),
#  ('Biological Process::GO:0002480', 'Biological Process'),
#  ('Biological Process::GO:0002481', 'Biological Process'),
#  ('Biological Process::GO:0002483', 'Biological Process'),
#  ('Biological Process::GO:0002484', 'Biological Process'),
#  ('Biological Process::GO:0002485', 'Biological Process'),
#  ('Biological Process::GO:0002486', 'Biological Process'),
#  ('Biological Process::GO:0002488', 'Biological Process'),
#  ('Biological Process::GO:0002489', 'Biological Process'),
#  ('Biological Process::GO:0002495', 'Biological Process'),
#  ('Biological Process::GO:0002501', 'Biological Process'),
#  ('Biological Process::GO:0002503', 'Biological Process'),
#  ('Biological Process::GO:0002504', 'Biological Process'),
#  ('Biological Process::GO:0002505', 'Biological Process'),
#  ('Biological Process::GO:0002506', 'Biological Process'),
#  ('Biological Process::GO:0002507', 'Biological Process'),
#  ('Biological Process::GO:0002513', 'Biological Process'),
#  ('Biological Process::GO:0002519', 'Biological Process'),
#  ('Biological Process::GO:0002520', 'Biological Process'),
#  ('Biological Process::GO:0002521', 'Biological Process'),
#  ('Biological Process::GO:0002522', 'Biological Process'),
#  ('Biological Process::GO:0002523', 'Biological Process'),
#  ('Biological Process::GO:0002526', 'Biological Process'),
#  ('Biological Process::GO:0002528', 'Biological Process'),
#  ('Biological Process::GO:0002532', 'Biological Process'),
#  ('Biological Process::GO:0002534', 'Biological Process'),
#  ('Biological Process::GO:0002537', 'Biological Process'),
#  ('Biological Process::GO:0002542', 'Biological Process'),
#  ('Biological Process::GO:0002543', 'Biological Process'),
#  ('Biological Process::GO:0002544', 'Biological Process'),
#  ('Biological Process::GO:0002548', 'Biological Process'),
#  ('Biological Process::GO:0002551', 'Biological Process'),
#  ('Biological Process::GO:0002553', 'Biological Process'),
#  ('Biological Process::GO:0002554', 'Biological Process'),
#  ('Biological Process::GO:0002562', 'Biological Process'),
#  ...]

# %%
# Create a graph
G = nx.MultiDiGraph()

# Add nodes with types
for node_id, node_type in nodes_stripped:
    G.add_node(node_id, type=node_type)

# Add edges with types
for source, edge_type, target in edges_data:
    G.add_edge(source, target, type=edge_type)

# Count different types for nodes
node_types = {node_attrs['type'] for _, node_attrs in G.nodes(data=True)}

# Count different types for edges
edge_types = {edge_attrs['type'] for _, _, edge_attrs in G.edges(data=True)}

H = G.to_directed()

# Print counts
print("Different types for nodes:", len(node_types))
print("Different types for edges:", len(edge_types))
# Out:
# Different types for nodes: 11
# Different types for edges: 24

# %%
# Count nodes associated with each type
node_counts = {}
for node, node_attrs in G.nodes(data=True):
    node_type = node_attrs['type']
    if node_type not in node_counts:
        node_counts[node_type] = 1
    else:
        node_counts[node_type] += 1

# Count edges associated with each type
edge_counts = {}
for _, _, edge_attrs in G.edges(data=True):
    edge_type = edge_attrs['type']
    if edge_type not in edge_counts:
        edge_counts[edge_type] = 1
    else:
        edge_counts[edge_type] += 1

# Print counts
#List the Total Number of Entities for Each Unique Kind
print("Nodes associated with each type:")
for node_type, count in node_counts.items():
    print(f"{node_type}: {count}")

print("\nEdges associated with each type:")
for edge_type, count in edge_counts.items():
    print(f"{edge_type}: {count}")
# Out:
# Nodes associated with each type:
# Anatomy: 402
# Biological Process: 11381
# Cellular Component: 1391
# Compound: 1552
# Disease: 137
# Gene: 20945
# Molecular Function: 2884
# Pathway: 1822
# Pharmacologic Class: 345
# Side Effect: 5734
# Symptom: 438
#
# Edges associated with each type:
# AdG: 102240
# AeG: 526407
# AuG: 97848
# CrC: 6486
# CtD: 755
# CbG: 11571
# CuG: 18756
# CcSE: 138944
# CdG: 21102
# CpD: 390
# DdG: 7623
# DpS: 3357
# DlA: 3602
# DrD: 543
# DaG: 12623
# DuG: 7731
# GiG: 147164
# GpCC: 73566
# GpBP: 559504
# GcG: 61690
# GpMF: 97222
# GpPW: 84372
# Gr>G: 265672
# PCiC: 1029

# %%
# H is our direct graph
from collections import defaultdict

# Initialize dictionaries to sum degrees and count nodes for each type
in_degrees = defaultdict(int)
out_degrees = defaultdict(int)
counts = defaultdict(int)

for node, attrs in H.nodes(data=True):
    node_type = attrs['type']
    counts[node_type] += 1
    in_degrees[node_type] += H.in_degree(node)
    out_degrees[node_type] += H.out_degree(node)

# Calculate and print average in/out-degrees
avg_in_degrees = {node_type: in_deg / counts[node_type] for node_type, in_deg in in_degrees.items()}
avg_out_degrees = {node_type: out_deg / counts[node_type] for node_type, out_deg in out_degrees.items()}

print("Average In-Degree for each node type:")
for node_type, avg_in in avg_in_degrees.items():
    print(f"{node_type}: {avg_in}")

print("\nAverage Out-Degree for each node type:")
for node_type, avg_out in avg_out_degrees.items():
    print(f"{node_type}: {avg_out}")
# Out:
# Average In-Degree for each node type:
# Anatomy: 8.960199004975124
# Biological Process: 49.16123363500571
# Cellular Component: 52.887131560028756
# Compound: 4.842139175257732
# Disease: 12.321167883211679
# Gene: 61.1328240630222
# Molecular Function: 33.71081830790569
# Pathway: 46.30735455543359
# Pharmacologic Class: 0.0
# Side Effect: 24.231600976630624
# Symptom: 7.664383561643835
#
# Average Out-Degree for each node type:
# Anatomy: 1807.2014925373135
# Biological Process: 0.0
# Cellular Component: 0.0
# Compound: 127.5798969072165
# Disease: 258.97080291970804
# Gene: 61.55120553831463
# Molecular Function: 0.0
# Pathway: 0.0
# Pharmacologic Class: 2.982608695652174
# Side Effect: 0.0
# Symptom: 0.0

# %%
# Filter out the disease nodes
disease_nodes = [node for node, attrs in H.nodes(data=True) if attrs['type'] == 'Disease']

# Compute in-degrees and out-degrees for each disease node
disease_degrees = [(node, H.in_degree(node), H.out_degree(node)) for node in disease_nodes]

# Sort the list by in-degree and out-degree to find the most connected diseases
most_connected_by_in_degree = sorted(disease_degrees, key=lambda x: x[0], reverse=True)
most_connected_by_out_degree = sorted(disease_degrees, key=lambda x: x[1], reverse=True)

# Display the top 5 most connected diseases by in-degree, assuming the name is in position 1
print("Top 5 diseases by in-degree (most incoming connections):")
for disease, in_degree, _ in most_connected_by_in_degree[:5]:
    # Assuming the name is stored under index 1 in the node attributes
    disease_name = H.nodes[disease][0] if 0 in H.nodes[disease] else "Unknown"
    print(f"Disease: {disease_name}, In-Degree: {in_degree}")

# Display the top 5 most connected diseases by out-degree, with the same assumption
print("\nTop 5 diseases by out-degree (most outgoing connections):")
for disease, _, out_degree in most_connected_by_out_degree[:5]:
    disease_name = H.nodes[disease][0] if 0 in H.nodes[disease] else "Unknown"
    print(f"Disease: {disease_name}, Out-Degree: {out_degree}")
# Out:
# Top 5 diseases by in-degree (most incoming connections):
# Disease: Unknown, In-Degree: 14
# Disease: Unknown, In-Degree: 0
# Disease: Unknown, In-Degree: 1
# Disease: Unknown, In-Degree: 3
# Disease: Unknown, In-Degree: 5
#
# Top 5 diseases by out-degree (most outgoing connections):
# Disease: Unknown, Out-Degree: 699
# Disease: Unknown, Out-Degree: 1076
# Disease: Unknown, Out-Degree: 1115
# Disease: Unknown, Out-Degree: 277
# Disease: Unknown, Out-Degree: 595

# %%
# Inspect the first few nodes to see how their attributes are stored
for node, attrs in list(H.nodes(data=True))[:5]:
    print(node, attrs)
# Out:
# Anatomy::UBERON:0000002 {'type': 'Anatomy'}
# Anatomy::UBERON:0000004 {'type': 'Anatomy'}
# Anatomy::UBERON:0000006 {'type': 'Anatomy'}
# Anatomy::UBERON:0000007 {'type': 'Anatomy'}
# Anatomy::UBERON:0000010 {'type': 'Anatomy'}
